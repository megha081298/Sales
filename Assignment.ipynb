# %%
import pandas as pd

# %%
df=pd.read_excel(r"/Users/apple/Downloads/Orders 1 updated (1).xlsx",index_col=[0])

# %%
df
# Out:
#               Order ID  Ship Date       Ship Mode VendorID Customer ID  \
# Row ID
# 1       CA-2016-152156 2016-11-11    Second Class    VEN02    CG-12520
# 2       CA-2016-152156 2016-11-11    Second Class    VEN02    CG-12520
# 3       CA-2016-138688 2016-06-16    Second Class    VEN04    DV-13045
# 4       US-2015-108966 2015-10-18  Standard Class    VEN01    SO-20335
# 5       US-2015-108966 2015-10-18  Standard Class    VEN02    SO-20335
# ...                ...        ...             ...      ...         ...
# 9990    CA-2014-110422 2014-01-23    Second Class    VEN04    TB-21400
# 9991    CA-2017-121258 2017-03-03  Standard Class    VEN04    DB-13060
# 9992    CA-2017-121258 2017-03-03  Standard Class    VEN05    DB-13060
# 9993    CA-2017-121258 2017-03-03  Standard Class    VEN01    DB-13060
# 9994    CA-2017-119914 2017-09-05    Second Class    VEN05    CC-12220
#
#              Product ID         Category Sub-Category Product Name     Sales  \
# Row ID
# ...

# %%
df.describe(include="all")
# Out:
# <ipython-input-6-7150bae0ffd8>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include="all")
#               Order ID            Ship Date       Ship Mode VendorID  \
# count             9994                 9994            9994     9994
# unique            5009                 1334               4        5
# top     CA-2017-100111  2015-12-16 00:00:00  Standard Class    VEN05
# freq                14                   35            5968     2035
# first              NaN  2014-01-07 00:00:00             NaN      NaN
# last               NaN  2018-01-05 00:00:00             NaN      NaN
# mean               NaN                  NaN             NaN      NaN
# std                NaN                  NaN             NaN      NaN
# ...

# %%
df.shape
# Out:
# (9994, 14)

# %%
df.dtypes
# Out:
# Order ID                   object
# Ship Date          datetime64[ns]
# Ship Mode                  object
# VendorID                   object
# Customer ID                object
# Product ID                 object
# Category                   object
# Sub-Category               object
# Product Name               object
# Sales                     float64
# Quantity                    int64
# Discount                  float64
# Profit                    float64
# Profit in USD $           float64
# dtype: object

# %%
df["Category"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["Category"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
pd.crosstab(df["Category"],df["Sub-Category"])
# Out:
# Sub-Category     Accessories  Appliances  Art  Binders  Bookcases  Chairs  \
# Category
# Furniture                  0           0    0        0        228     617
# Office Supplies            0         466  796     1523          0       0
# Technology               775           0    0        0          0       0
#
# Sub-Category     Copiers  Envelopes  Fasteners  Furnishings  Labels  Machines  \
# Category
# Furniture              0          0          0          957       0         0
# Office Supplies        0        254        217            0     364         0
# Technology            68          0          0            0       0       115
#
# Sub-Category     Paper  Phones  Storage  Supplies  Tables
# Category
# Furniture            0       0        0         0     319
# Office Supplies   1370       0      846       190       0
# Technology           0     889        0         0       0

# %%
df["Sales"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df["Sales"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                     Sales  Quantity  Discount    Profit  Profit in USD $
# Sales            1.000000  0.200795 -0.028190  0.479064         0.479064
# Quantity         0.200795  1.000000  0.008623  0.066253         0.066253
# Discount        -0.028190  0.008623  1.000000 -0.219487        -0.219487
# Profit           0.479064  0.066253 -0.219487  1.000000         1.000000
# Profit in USD $  0.479064  0.066253 -0.219487  1.000000         1.000000

# %%
df
# Out:
#               Order ID  Ship Date       Ship Mode VendorID Customer ID  \
# Row ID
# 1       CA-2016-152156 2016-11-11    Second Class    VEN02    CG-12520
# 2       CA-2016-152156 2016-11-11    Second Class    VEN02    CG-12520
# 3       CA-2016-138688 2016-06-16    Second Class    VEN04    DV-13045
# 4       US-2015-108966 2015-10-18  Standard Class    VEN01    SO-20335
# 5       US-2015-108966 2015-10-18  Standard Class    VEN02    SO-20335
# ...                ...        ...             ...      ...         ...
# 9990    CA-2014-110422 2014-01-23    Second Class    VEN04    TB-21400
# 9991    CA-2017-121258 2017-03-03  Standard Class    VEN04    DB-13060
# 9992    CA-2017-121258 2017-03-03  Standard Class    VEN05    DB-13060
# 9993    CA-2017-121258 2017-03-03  Standard Class    VEN01    DB-13060
# 9994    CA-2017-119914 2017-09-05    Second Class    VEN05    CC-12220
#
#              Product ID         Category Sub-Category Product Name     Sales  \
# Row ID
# ...

# %%
Find which category is the highest selling in the dataset

# %%
y=df.loc[(df.Category=="Furniture")]

# %%
y
# Out:
#               Order ID  Ship Date       Ship Mode VendorID Customer ID  \
# Row ID
# 1       CA-2016-152156 2016-11-11    Second Class    VEN02    CG-12520
# 2       CA-2016-152156 2016-11-11    Second Class    VEN02    CG-12520
# 4       US-2015-108966 2015-10-18  Standard Class    VEN01    SO-20335
# 6       CA-2014-115812 2014-06-14  Standard Class    VEN01    BH-11710
# 11      CA-2014-115812 2014-06-14  Standard Class    VEN05    BH-11710
# ...                ...        ...             ...      ...         ...
# 9963    CA-2015-168088 2015-03-22     First Class    VEN04    CM-12655
# 9965    CA-2016-146374 2016-12-10    Second Class    VEN03    HE-14800
# 9981    US-2015-151435 2015-09-09    Second Class    VEN05    SW-20455
# 9990    CA-2014-110422 2014-01-23    Second Class    VEN04    TB-21400
# 9991    CA-2017-121258 2017-03-03  Standard Class    VEN04    DB-13060
#
#              Product ID   Category Sub-Category Product Name      Sales  \
# Row ID
# ...

# %%
x.describe()
# Out:
#              Sales     Quantity     Discount       Profit  Profit in USD $
# count  2121.000000  2121.000000  2121.000000  2121.000000      2121.000000
# mean    349.834887     3.785007     0.173923     8.699327         0.104811
# std     503.179145     2.251620     0.181547   136.049246         1.639148
# min       1.892000     1.000000     0.000000 -1862.312400       -22.437499
# 25%      47.040000     2.000000     0.000000   -12.849000        -0.154807
# 50%     182.220000     3.000000     0.200000     7.774800         0.093672
# 75%     435.168000     5.000000     0.300000    33.726600         0.406345
# max    4416.174000    14.000000     0.700000  1013.127000        12.206349

# %%
Office_sale=sum(x["Sales"])

# %%
furniture_sal=sum(y["Sales"])

# %%
Office_sale
# Out:
# 719047.0320000029

# %%
furniture_sal
# Out:
# 741999.7952999998

# %%
max(Office_sale,furniture_sal,Technology_sale)
# Out:
# 836154.0329999966

# %%
z=df.loc[(df.Category=="Technology")]

# %%
z
# Out:
#               Order ID  Ship Date       Ship Mode VendorID Customer ID  \
# Row ID
# 8       CA-2014-115812 2014-06-14  Standard Class    VEN05    BH-11710
# 12      CA-2014-115812 2014-06-14  Standard Class    VEN03    BH-11710
# 20      CA-2014-143336 2014-09-01    Second Class    VEN01    ZD-21925
# 27      CA-2016-121755 2016-01-20    Second Class    VEN05    EH-13945
# 36      CA-2016-117590 2016-12-10     First Class    VEN04    GH-14485
# ...                ...        ...             ...      ...         ...
# 9984    US-2016-157728 2016-09-28  Standard Class    VEN01    RC-19960
# 9987    CA-2016-125794 2016-10-03  Standard Class    VEN01    ML-17410
# 9988    CA-2017-163629 2017-11-21  Standard Class    VEN05    RA-19885
# 9989    CA-2017-163629 2017-11-21  Standard Class    VEN02    RA-19885
# 9992    CA-2017-121258 2017-03-03  Standard Class    VEN05    DB-13060
#
#              Product ID    Category Sub-Category Product Name     Sales  \
# Row ID
# ...

# %%
Technology_sale=sum(z["Sales"])
